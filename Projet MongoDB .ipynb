# %%
import tkinter
import tkinter.ttk
import pymongo
from pprint import pprint
from pymongo import MongoClient

#On se connecte à MongoDB
client = MongoClient("localhost", 27017) 

#Permet de rentrer dans la base de donnée DbRestaurant
Dbresto = client["DbRestaurant"]
Resto = Dbresto.get_collection("ListeRestaurant")

# La fenetre de l'application
window = tkinter.Tk()

# Nom de la fentre
window.title("Restaurants")

#Création du Tableau

content = ttk.Frame(window, padding=(3,3,12,12))
Tableau = ttk.Treeview(content)

Tableau["columns"]= ("_id", "Nom", "Adresse", "Ville","Code Postal","Téléphone","Halal","Notes","Type","Fast-Food","Jour0","Ouverture","Fermeture","Jour1","Ouverture_1","Fermeture_1","Jour2","Ouverture_2","Fermeture_2","Jour3","Ouverture_3","Fermeture_3","Jour4","Ouverture_4","Fermeture_4","Jour5","Ouverture_5","Fermeture_5","Jour6","Ouverture_6","Fermeture_6","SiteWeb")

Tableau.column ( "#0" , stretch=False, width=0 )
Tableau.column("_id", stretch=False, width=150)
Tableau.column("Nom", stretch=False, width=100)
Tableau.column("Adresse", stretch=False, width=100)
Tableau.column("Ville", stretch=False, width=100)
Tableau.column("Code Postal", stretch=False, width=150)
Tableau.column("Téléphone", stretch=False, width=100)
Tableau.column("Halal", stretch=False, width=100)
Tableau.column("Notes", stretch=False, width=100)
Tableau.column("Type", stretch=False, width=150)
Tableau.column("Fast-Food", stretch=False, width=100)
Tableau.column("Jour0", stretch=False, width=100)
Tableau.column("Ouverture", stretch=False, width=100)
Tableau.column("Fermeture", stretch=False, width=150)
Tableau.column("Jour1", stretch=False, width=100)
Tableau.column("Ouverture_1", stretch=False, width=100)
Tableau.column("Fermeture_1", stretch=False, width=100)
Tableau.column("Jour2", stretch=False, width=100)
Tableau.column("Ouverture_2", stretch=False, width=100)
Tableau.column("Fermeture_2", stretch=False, width=150)
Tableau.column("Jour3", stretch=False, width=100)
Tableau.column("Ouverture_3", stretch=False, width=100)
Tableau.column("Fermeture_3", stretch=False, width=100)
Tableau.column("Jour4", stretch=False, width=150)
Tableau.column("Ouverture_4", stretch=False, width=100)
Tableau.column("Fermeture_4", stretch=False, width=100)
Tableau.column("Jour5", stretch=False, width=150)
Tableau.column("Ouverture_5", stretch=False, width=100)
Tableau.column("Fermeture_5", stretch=False, width=100)
Tableau.column("Jour6", stretch=False, width=150)
Tableau.column("Ouverture_6", stretch=False, width=100)
Tableau.column("Fermeture_6", stretch=False, width=100)
Tableau.column("SiteWeb", stretch=False, width=100)


Tableau.heading ( "#0" , text = "_id" , anchor = "w" )
Tableau.heading("_id", text="_id")
Tableau.heading("Nom", text="Nom")
Tableau.heading("Adresse", text="Adresse")
Tableau.heading("Ville", text="Ville")
Tableau.heading("Code Postal", text="Code Postal")
Tableau.heading("Téléphone", text="Téléphone")
Tableau.heading("Halal", text="Halal")
Tableau.heading("Notes", text="Notes")
Tableau.heading("Type", text="Type")
Tableau.heading("Fast-Food", text="Fast-Food")
Tableau.heading("Jour0", text="Jour0")
Tableau.heading("Ouverture", text="Ouverture")
Tableau.heading("Fermeture", text="Fermeture")
Tableau.heading("Jour1", text="Jour1")
Tableau.heading("Ouverture_1", text="Ouverture_1")
Tableau.heading("Fermeture_1", text="Fermeture_1")
Tableau.heading("Jour2", text="Jour2")
Tableau.heading("Ouverture_2", text="Ouverture_2")
Tableau.heading("Fermeture_2", text="Fermeture_2")
Tableau.heading("Jour3", text="Jour3")
Tableau.heading("Ouverture_3", text="Ouverture_3")
Tableau.heading("Fermeture_3", text="Fermeture_3")
Tableau.heading("Jour4", text="Jour4")
Tableau.heading("Ouverture_4", text="Ouverture_4")
Tableau.heading("Fermeture_4", text="Fermeture_4")
Tableau.heading("Jour5", text="Jour5")
Tableau.heading("Ouverture_5", text="Ouverture_5")
Tableau.heading("Fermeture_5", text="Fermeture_5")
Tableau.heading("Jour6", text="Jour7")
Tableau.heading("Ouverture_6", text="Ouverture_6")
Tableau.heading("Fermeture_6", text="Fermeture_6")
Tableau.heading("SiteWeb", text="SiteWeb")


Tableau.pack ( )

####Création des scrollbars attacher à la frame#####


# Horizontale
ScrollX = ttk.Scrollbar(window, orient = HORIZONTAL)
ScrollX.configure(command=Tableau.xview)
Tableau.configure(xscrollcommand=ScrollX.set)
ScrollX.grid(column=0, row=6, columnspan=3, sticky=W + E)


# Verticale
ScrollY = ttk.Scrollbar(window, orient=VERTICAL)
ScrollY.configure(command=Tableau.yview)
Tableau.configure(yscrollcommand=ScrollY.set)
ScrollY.grid(column=6, row=0, columnspan=1, sticky=N + S)


# Permet de gérer le redimensionnement 
window.columnconfigure(0, weight=1)
window.rowconfigure(0, weight=1)
content.columnconfigure(0, weight=3)
content.columnconfigure(1, weight=3)
content.columnconfigure(2, weight=3)
content.columnconfigure(3, weight=1)
content.columnconfigure(4, weight=1)
content.rowconfigure(1, weight=1)


#-----------------------Afficher les restaurants------------------------------------------------------------------
#Affiche tout
query = Resto.find()

#Queries "Notes"
QNote1 = Resto.find({"Notes":{"$lte": 1}})
QNote2 = Resto.find({"Notes":{"$lte": 2}})
QNote3 = Resto.find({"Notes":{"$lte": 3}})
QNote4 = Resto.find({"Notes":{"$lte": 4}})
QNote5 = Resto.find({"Notes":{"$lte": 5}})
QNote6 = Resto.find({"Notes":{"$lte": 0}})

#Query "Halal"
QHalal1 = Resto.find({"Halal":True})
QHalal2 = Resto.find({"Halal":False})

#Query "FastFood"
QFast1 = Resto.find({"Fast-Food":True})
QFast2 = Resto.find({"Fast-Food":False})

#Query "Jours"
QJours1 = Resto.find({"Jour0":"Lundi"})
QJours2 = Resto.find({"Jour1":"Mardi"})
QJours3 = Resto.find({"Jour2":"Mercredi"})
QJours4 = Resto.find({"Jour3":"Jeudi"})
QJours5 = Resto.find({"Jour4":"Vendredi"})
QJours6 = Resto.find({"Jour5":"Samedi"})
QJours7 = Resto.find({"Jour6":"Dimanche"})


#Fontions des filtres

def Var_halal():
   if Halal.get() == True :  
    for item in QHalal1:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if Halal.get() == False :  
    for item in QHalal2:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )

def Var_FastFood():
   if FastFood.get() == True :  
    for item in QFast1:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if FastFood.get() == False :  
    for item in QFast2:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )

def Var_Jours():
   if Lundi.get() == True :  
    for item in QJours1:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if Mardi.get() == True :  
    for item in QJours2:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if Mercredi.get() == True :  
    for item in QJours3:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if Jeudi.get() == True :  
    for item in QJours4:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if Vendredi.get() == True :  
    for item in QJours5:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if Samedi.get() == True :  
    for item in QJours6:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if Dimanche.get() == True : 
    for item in QJour7:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )

def Var_Notes():
   if un.get() == True :  
    for item in QNote1:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if deux.get() == True :  
    for item in QNote2:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if trois.get() == True :  
    for item in QNote3:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if quatre.get() == True :  
    for item in QNote4:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )
   if cinq.get() == True :  
    for item in QNote5:
        Tableau.insert ( "" ,"end", values = ( item["_id"],item["Nom"],item["Adresse"],item["Ville"],item["Code Postal"],item["Telephone"],item["Halal"],item["Notes"],item["Type"],item["Fast-Food"],item["Jour0"],item["Ouverture"],item["Fermeture"],item["Jour1"],item["Ouverture__1"],item["Fermeture__1"],item["Jour2"],item["Ouverture__2"],item["Fermeture__2"],item["Jour3"],item["Ouverture__3"],item["Fermeture__3"],item["Jour4"],item["Ouverture__4"],item["Fermeture__4"],item["Jour5"],item["Ouverture__5"],item["Fermeture__5"],item["Jour6"],item["Ouverture__6"],item["Fermeture__6"],item["SiteWeb"]) )

#Variable permettant d'associer toute les fonctions en une seule
all_commands = lambda: [Var_halal(), Var_Notes(),Var_FastFood(),Var_Jours()]


#Boutons
Quitter = ttk.Button(window, text = "Quitter" , command = window.destroy )
Quitter.grid(column=0, row=10)
Tableau.grid(column=0, row=0, columnspan=3, rowspan=2, sticky=(N, S, E, W))
content.grid(column=0, row=0, sticky=(N, S, E, W))



#-----------------------Nouvelle fenetre pour les choix------------------------------------------------------------------

window2 = tkinter.Tk()
window2.title("Choix")

#Permet de définir la taille de la fenêtre
window2.geometry("340x480")

# Création du label frame Halal
radioGroup = LabelFrame(window2, text = "Halal")
radioGroup.pack(fill="both", expand="yes")

# Variables Halal
Halal = IntVar()

# Création des radio buttons Halal
H = Checkbutton(radioGroup,text="Oui", variable= Halal)
H.pack(anchor=W)


# Création du label frame FastFood
radioGroup2 = LabelFrame(window2, text = "Fast-Food")
radioGroup2.pack(fill="both", expand="yes")

# Variables Fastfood
FastFood = IntVar()

# Création des radio buttons FastFood

Fast= Checkbutton(radioGroup2,text="Oui", variable= FastFood)
Fast.pack(anchor=W)

# Création du label frame Jours
Jours = LabelFrame(window2, text = "Jours d'ouverture")
Jours.pack(fill="both", expand="yes")

# Variables Jours

Lundi = IntVar()
Mardi = IntVar()
Mercredi = IntVar()
Jeudi = IntVar()
Vendredi = IntVar()
Samedi = IntVar()
Dimanche = IntVar()

# Création des radio buttons Jours
JLundi = Checkbutton(Jours, text="Lundi", variable= Lundi)
JLundi.pack()

JMardi = Checkbutton(Jours, text="Mardi", variable= Mardi)
JMardi.pack()

JMercredi = Checkbutton(Jours, text="Mercredi", variable= Mercredi)
JMercredi.pack()

JJeudi = Checkbutton(Jours, text="Jeudi", variable= Jeudi)
JJeudi.pack()

JVendredi = Checkbutton(Jours, text="Vendredi", variable= Vendredi)
JVendredi.pack()

JSamedi = Checkbutton(Jours, text="Samedi", variable= Samedi)
JSamedi.pack()

JDimanche = Checkbutton(Jours, text="Dimanche", variable= Dimanche)
JDimanche.pack()


# Création du label frame Notes
Notes = LabelFrame(window2, text = "Notes")
Notes.pack(fill="both", expand="yes")

# Variables Notes
zero = IntVar()
un = IntVar()
deux = IntVar()
trois = IntVar()
quatre = IntVar()
cinq = IntVar()

# Création des radio buttons Notes
Nzero = Checkbutton(Notes, text=" 1",variable=un)
Nzero.pack(anchor=W)

Nun = Checkbutton(Notes, text=" 2",variable=deux)
Nun.pack(anchor=W)

Ndeux = Checkbutton(Notes, text=" 3",variable=trois)
Ndeux.pack(anchor=W)

Ntrois = Checkbutton(Notes, text=" 4",variable=quatre)
Ntrois.pack(anchor=W)

NQuatre = Checkbutton(Notes, text=" 5",variable=cinq)
NQuatre.pack(anchor=W)


#Bouttons dans la nouvelle fenetre


ok = ttk.Button(window2, text="Ok",command = all_commands)
Quitter = ttk.Button(window2, text = "Quitter" , command = window2.destroy)
ok.pack(side=BOTTOM)
Quitter.pack(side= BOTTOM)


window.mainloop()
